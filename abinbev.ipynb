# %%
import pandas as pd

# %%
df = pd.read_excel("C:\Users\SRIRAMYA NITTALA\Downloads\M&CI Case Study - Data.xlsx", sheet_name= "Raw Data")

# %%
df
# Out:
#                Market             Segments TRADING COMPANY -Manufacturers
# 0      Total Coverage  Total Beer Category            Total Beer Category  \
# 1      Total Coverage  Total Beer Category            Total Beer Category
# 2      Total Coverage                  ALE     All Others - Manufacturers
# 3      Total Coverage                  ALE     All Others - Manufacturers
# 4      Total Coverage                  ALE     All Others - Manufacturers
# ...               ...                  ...                            ...
# 18033  Total Coverage           UNASSIGNED     All Others - Manufacturers
# 18034  Total Coverage           UNASSIGNED           Comp. Manufacturer 2
# 18035  Total Coverage           UNASSIGNED           Comp. Manufacturer 2
# 18036  Total Coverage           UNASSIGNED     All Others - Manufacturers
# 18037  Total Coverage           UNASSIGNED     All Others - Manufacturers
#
#                     Brands       PACKAGING TYPE       NUMBER IN PACK
# 0      Total Beer Category  Total Beer Category  Total Beer Category  \
# 1      Total Beer Category  Total Beer Category  Total Beer Category
# 2      All Others - Brands                  BTL               SINGLE
# 3      All Others - Brands                  BTL               SINGLE
# 4      All Others - Brands                  CAN               SINGLE
# ...                    ...                  ...                  ...
# 18033  All Others - Brands                  BTL               3 PACK
# 18034  All Others - Brands                  BTL               4 PACK
# 18035  All Others - Brands                  BTL               4 PACK
# 18036  All Others - Brands                  BTL               4 PACK
# 18037  All Others - Brands                  BTL               4 PACK
#
#              WEIGHT VOLUME Measures/Metrics/KPIs       FY 2020       FY 2021
# 0      Total Beer Category          Value (£000)  5.710667e+06  5.506389e+06  \
# 1      Total Beer Category   Volume Litres (000)  2.309172e+06  2.206541e+06
# 2                   330 ML          Value (£000)  1.494950e+01  4.240800e+00
# 3                   330 ML   Volume Litres (000)  2.947100e+00  8.342000e-01
# 4                   440 ML          Value (£000)  0.000000e+00  0.000000e+00
# ...                    ...                   ...           ...           ...
# 18033               330 ML   Volume Litres (000)  0.000000e+00  0.000000e+00
# 18034               330 ML          Value (£000)  0.000000e+00  0.000000e+00
# 18035               330 ML   Volume Litres (000)  0.000000e+00  0.000000e+00
# 18036               330 ML          Value (£000)  0.000000e+00  0.000000e+00
# 18037               330 ML   Volume Litres (000)  0.000000e+00  0.000000e+00
#
#        ...     Feb 2022     Mar 2022     Apr 2022       May 22       Jun 22
# 0      ...  331789.4957  435909.7251  387263.1597  393152.6911  520061.7222  \
# 1      ...  129580.3699  170560.0092  154366.6784  152713.5019  203415.6934
# 2      ...       0.0000       0.0000       0.0000       0.0000       0.0000
# 3      ...       0.0000       0.0000       0.0000       0.0000       0.0000
# 4      ...       0.0000       0.0000       0.0000       0.0000       0.0000
# ...    ...          ...          ...          ...          ...          ...
# 18033  ...       0.0000       0.0000       0.0000       0.0000       0.0000
# 18034  ...       0.0000       0.0000       0.0000       0.0000       0.0000
# 18035  ...       0.0000       0.0000       0.0000       0.0000       0.0000
# 18036  ...       0.0000       0.0000       0.0000       0.0000       0.0000
# 18037  ...       0.0000       0.0000       0.0000       0.0000       0.0000
#
#             Jul 22       Aug 22       Sep-22    YTD-Sep 21    YTD-Sep 22
# 0      437306.7014  430255.5813  451757.1885  4.243830e+06  3.670889e+06
# 1      168200.1233  165984.9433  171964.6871  1.691236e+06  1.427760e+06
# 2           0.0000       0.0000       0.0000  4.240800e+00  0.000000e+00
# 3           0.0000       0.0000       0.0000  8.342000e-01  0.000000e+00
# 4           0.0000       0.0000       0.0000  0.000000e+00  0.000000e+00
# ...            ...          ...          ...           ...           ...
# 18033       0.0000       0.0000       0.0000  0.000000e+00  0.000000e+00
# 18034       0.0000       0.0000       3.1067  0.000000e+00  3.106700e+00
# 18035       0.0000       0.0000       0.8210  0.000000e+00  8.210000e-01
# 18036       0.0000       0.0000       0.0000  0.000000e+00  0.000000e+00
# 18037       0.0000       0.0000       0.0000  0.000000e+00  0.000000e+00
#
# [18038 rows x 45 columns]

# %%
df['PACKAGING TYPE'].value_counts()
# Out:
# PACKAGING TYPE
# BTL                    10436
# CAN                     7344
# KEG                      220
# PLASTIC BOTTLE            20
# ALUMINIUM BOTTLE          10
# POUCH                      4
# Total Beer Category        2
# BOX                        2
# Name: count, dtype: int64

# %%
df['WEIGHT VOLUME'].value_counts()
# Out:
# WEIGHT VOLUME
# 500 ML                 6254
# 330 ML                 5926
# 440 ML                 3084
# 355 ML                  398
# 568 ML                  390
# 300 ML                  264
# 660 ML                  256
# 275 ML                  252
# ESTIMATED WEIGHT        232
# 5 L                     136
# 250 ML                  126
# 750 ML                  106
# 284 ML                   72
# 375 ML                   64
# 6 L                      50
# 650 ML                   48
# 400 ML                   42
# 350 ML                   40
# 620 ML                   38
# 550 ML                   36
# 2 L                      20
# 450 ML                   20
# 1 L                      20
# 473 ML                   16
# 8 L                      14
# 470 ML                   12
# 640 ML                   12
# 600 ML                   12
# 710 ML                    8
# 484 ML                    8
# 1890 ML                   8
# 30 L                      6
# 333 ML                    6
# 630 ML                    6
# 520 ML                    4
# 625 ML                    4
# 320 ML                    4
# 340 ML                    4
# 325 ML                    4
# 538ML                     4
# 3 L                       4
# 970 ML                    2
# 2.5 L                     2
# 700 ML                    2
# Total Beer Category       2
# 210 ML                    2
# 5000 ML                   2
# 207 ML                    2
# 580 ML                    2
# 1.5 L                     2
# 335 ML                    2
# 680 ML                    2
# 850 ML                    2
# 530 ML                    2
# 20 L                      2
# Name: count, dtype: int64

# %%
df['NUMBER IN PACK'].value_counts()
# Out:
# NUMBER IN PACK
# SINGLE                 12596
# 4 PACK                  2710
# 12 PACK                  718
# 6 PACK                   654
# 10 PACK                  306
# 24 PACK                  272
# 8 PACK                   232
# 15 PACK                  152
# 3 PACK                   114
# 20 PACK                  100
# 18 PACK                   96
# 2 PACK                    60
# UNIDENTIFIED               8
# 9 PACK                     8
# 5 PACK                     6
# Total Beer Category        2
# 17 PACK                    2
# 30 PACK                    2
# Name: count, dtype: int64

# %%
df['TRADING COMPANY -Manufacturers'].value_counts()
# Out:
# TRADING COMPANY -Manufacturers
# All Others - Manufacturers    11056
# Focus Manufacturer             1710
# Comp. Manufacturer 2           1566
# Comp. Manufacturer 1           1260
# Comp. Manufacturer 3            834
# Comp. Manufacturer 4            724
# Comp. Manufacturer 6            488
# Comp. Manufacturer 5            398
# Total Beer Category               2
# Name: count, dtype: int64

# %%
beer_counts=df['Segments'].value_counts()

# %%
beer_counts
# Out:
# Segments
# CRAFT                  5250
# ALE                    5222
# PREMIUM LAGER          2038
# WORLD BEER             1714
# STANDARD LAGER         1678
# STOUT                   584
# SPECIALITY              500
# NABLAB LAGER            286
# NABLAB ALE              264
# UNASSIGNED              258
# FLAVOURED               178
# GINGER BEER              64
# Total Beer Category       2
# Name: count, dtype: int64

# %%
conda install matplotlib
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.5.0
#
#
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
plt.bar(beer_counts.index, beer_counts.values)
plt.xlabel('Beer Type')
plt.ylabel('Sales')
plt.title('Beer Sales by Type')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %%
df['Brands'].value_counts()
# Out:
# Brands
# All Others - Brands    15464
# Comp. Brand 2            464
# Comp. Brand 6            382
# Comp. Brand 9            368
# Focus Brand              356
# Comp. Brand 3            264
# Comp. Brand 4            194
# Comp. Brand 1            188
# Comp. Brand 5            150
# Comp. Brand 8            124
# Comp. Brand 7             82
# Total Beer Category        2
# Name: count, dtype: int64

# %%
df1=df[df['Brands'] == "Focus Brand" ]

# %%
pack_counts=df1['NUMBER IN PACK'].value_counts()

# %%
pack_counts
# Out:
# NUMBER IN PACK
# SINGLE     94
# 4 PACK     94
# 6 PACK     36
# 12 PACK    28
# 10 PACK    24
# 15 PACK    24
# 24 PACK    20
# 20 PACK    18
# 8 PACK     10
# 18 PACK     6
# 30 PACK     2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
plt.bar(pack_counts.index, (pack_counts.values)/2)
plt.xlabel('Pack name')
plt.ylabel('no of packs')
plt.title('Beer Sales by Type')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %%
data=df[df['Segments'] == "CRAFT" ]

# %%
data
# Out:
#                Market Segments TRADING COMPANY -Manufacturers
# 5872   Total Coverage    CRAFT     All Others - Manufacturers  \
# 5873   Total Coverage    CRAFT     All Others - Manufacturers
# 5874   Total Coverage    CRAFT     All Others - Manufacturers
# 5875   Total Coverage    CRAFT     All Others - Manufacturers
# 5876   Total Coverage    CRAFT     All Others - Manufacturers
# ...               ...      ...                            ...
# 11117  Total Coverage    CRAFT     All Others - Manufacturers
# 11118  Total Coverage    CRAFT     All Others - Manufacturers
# 11119  Total Coverage    CRAFT     All Others - Manufacturers
# 11120  Total Coverage    CRAFT     All Others - Manufacturers
# 11121  Total Coverage    CRAFT     All Others - Manufacturers
#
#                     Brands PACKAGING TYPE NUMBER IN PACK WEIGHT VOLUME
# 5872   All Others - Brands            CAN         SINGLE        440 ML  \
# 5873   All Others - Brands            CAN         SINGLE        440 ML
# 5874   All Others - Brands            CAN         SINGLE        440 ML
# 5875   All Others - Brands            CAN         SINGLE        440 ML
# 5876   All Others - Brands            CAN         SINGLE        440 ML
# ...                    ...            ...            ...           ...
# 11117  All Others - Brands            CAN         SINGLE        330 ML
# 11118  All Others - Brands            CAN         SINGLE        330 ML
# 11119  All Others - Brands            CAN         SINGLE        330 ML
# 11120  All Others - Brands            CAN         SINGLE        440 ML
# 11121  All Others - Brands            CAN         SINGLE        440 ML
#
#       Measures/Metrics/KPIs  FY 2020  FY 2021  ...  Feb 2022  Mar 2022
# 5872           Value (£000)   0.6692   0.0000  ...    0.0000    0.0000  \
# 5873    Volume Litres (000)   0.0539   0.0000  ...    0.0000    0.0000
# 5874           Value (£000)   0.0000   0.0000  ...    0.0000    0.0000
# 5875    Volume Litres (000)   0.0000   0.0000  ...    0.0000    0.0000
# 5876           Value (£000)   0.0000   0.0000  ...    0.0000    0.0000
# ...                     ...      ...      ...  ...       ...       ...
# 11117   Volume Litres (000)   0.9988   1.2066  ...    0.0228    0.1922
# 11118          Value (£000)  49.0450   3.1339  ...    0.1131    0.2217
# 11119   Volume Litres (000)  11.5442   0.5758  ...    0.0158    0.0318
# 11120          Value (£000)   0.0000   0.2534  ...    0.0000    0.0000
# 11121   Volume Litres (000)   0.0000   0.0333  ...    0.0000    0.0000
#
#        Apr 2022  May 22  Jun 22  Jul 22  Aug 22  Sep-22  YTD-Sep 21
# 5872     0.0000  0.0000  0.0000  0.0000  0.0000  0.0000      0.0000  \
# 5873     0.0000  0.0000  0.0000  0.0000  0.0000  0.0000      0.0000
# 5874     0.0000  0.0000  0.0000  0.0000  0.0000  0.0000      0.0000
# 5875     0.0000  0.0000  0.0000  0.0000  0.0000  0.0000      0.0000
# 5876     0.0000  0.0000  0.0000  0.0000  0.0000  0.0000      0.0000
# ...         ...     ...     ...     ...     ...     ...         ...
# 11117    0.0063  0.0000  0.0000  0.0000  0.0000  0.0000      1.1846
# 11118    0.1121  0.0406  0.1706  0.0428  0.1022  0.0598      2.9911
# 11119    0.0144  0.0055  0.0240  0.0141  0.0226  0.0086      0.5566
# 11120    0.0000  0.0000  0.0000  0.0000  0.0000  0.0000      0.2534
# 11121    0.0000  0.0000  0.0000  0.0000  0.0000  0.0000      0.0333
#
#        YTD-Sep 22
# 5872       0.0000
# 5873       0.0000
# 5874       0.0000
# 5875       0.0000
# 5876       0.0000
# ...           ...
# 11117      0.2659
# 11118      0.9488
# 11119      0.1491
# 11120      0.0000
# 11121      0.0000
#
# [5250 rows x 45 columns]

# %%
df3 = pd.read_excel("C:\Users\SRIRAMYA NITTALA\Downloads\M&CI Case Study - Data.xlsx", sheet_name= "Social Media Advertising", usecols=range(8))

# %%
df3
# Out:
#       Platform        Placement  Gender         Spend  Impressions   Likes
# 0     Facebook   Instream Video     All  13323.890000       749893     1.0  \
# 1     Facebook             Feed     All   7600.328271      6053889   123.0
# 2     Facebook             Feed     All   1790.933931       727634  1211.0
# 3     Facebook             Feed  Female   7750.369014      4150945   109.0
# 4     Facebook             Feed    Male   1003.697658       157812    22.0
# ..         ...              ...     ...           ...          ...     ...
# 686  Instagram  Instagram Reels     All   3000.000000       482161  3971.0
# 687  Instagram  Instagram Reels     All    500.000000       106535   535.0
# 688  Instagram  Instagram Reels     All    500.000000       126170  1662.0
# 689  Instagram             Feed     All    499.990000       154483  1700.0
# 690  Instagram  Instagram Reels     All   1000.000000       175631   787.0
#
#      Shares  Comments
# 0       0.0       0.0
# 1       6.0      15.0
# 2     209.0     108.0
# 3       3.0      14.0
# 4       3.0      13.0
# ..      ...       ...
# 686     0.0      20.0
# 687     0.0       0.0
# 688     0.0       6.0
# 689     0.0       1.0
# 690     0.0      23.0
#
# [691 rows x 8 columns]

# %%
df3['Platform'].value_counts()
# Out:
# Platform
# Instagram    368
# Facebook     319
# YouTube        4
# Name: count, dtype: int64

# %%
data1=df3[df3['Platform'] == "Instagram"]

# %%
data1['Placement'].value_counts()
# Out:
# Placement
# Feed                 129
# Instagram Stories     89
# Instagram Explore     88
# Instagram Reels       62
# Name: count, dtype: int64

# %%
data1
# Out:
#       Platform          Placement  Gender        Spend  Impressions   Likes
# 5    Instagram  Instagram Stories  Female  7388.192194      5990437     0.0  \
# 12   Instagram  Instagram Stories  Female  3588.812349      2863318     0.0
# 15   Instagram  Instagram Stories  Female  2823.665306      1574187     0.0
# 16   Instagram  Instagram Stories  Female  2687.058739      2178593     0.0
# 28   Instagram               Feed  Female   293.591361        64069    45.0
# ..         ...                ...     ...          ...          ...     ...
# 686  Instagram    Instagram Reels     All  3000.000000       482161  3971.0
# 687  Instagram    Instagram Reels     All   500.000000       106535   535.0
# 688  Instagram    Instagram Reels     All   500.000000       126170  1662.0
# 689  Instagram               Feed     All   499.990000       154483  1700.0
# 690  Instagram    Instagram Reels     All  1000.000000       175631   787.0
#
#      Shares  Comments
# 5       0.0       0.0
# 12      0.0       0.0
# 15      0.0       0.0
# 16      0.0       0.0
# 28      0.0       1.0
# ..      ...       ...
# 686     0.0      20.0
# 687     0.0       0.0
# 688     0.0       6.0
# 689     0.0       1.0
# 690     0.0      23.0
#
# [368 rows x 8 columns]
